# %%
import numpy as np
import pandas as pd
from sqlalchemy import create_engine

# %%
movies = pd.read_csv(r"C:\Users\ishan\Desktop\machine learning\movie Recomandation system\dataset\movies info\tmdb_5000_movies.csv")
credits= pd.read_csv(r"C:\Users\ishan\Desktop\machine learning\movie Recomandation system\dataset\movies info\tmdb_5000_credits.csv")

# %%
movies
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
credits.head(2)
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...

# %%
movies = movies.merge(credits)

# %%
movies = movies[["id","original_title","genres","keywords","overview","cast","crew"]]

# %%
#getting genres
def get_genres(i):
    l=[]
    for j in eval(i):
        l.append(j["name"])
    return l


#getting keywords
def get_keywords(i):
    l=[]
    for j in eval(i):
        l.append(j["name"])
    return l

#getting top 5 cast name
def get_cast(i):
    l=[]
    s=0
    for j in eval(i):
        s+=1
        l.append(j["name"])
        if s==5:
            break
    return l

# %%
l=[]
for i in movies["genres"]:
    l.append(get_genres(i))
movies["genres"]=l

# %%
l=[]
for i in movies["keywords"]:
    l.append(get_genres(i))
movies["keywords"]=l

# %%
l=[]
for i in movies["cast"]:
    l.append(get_cast(i))
movies["cast"] = l

# %%
#getting director name
l=[]
for j in range(0,4809):
    l1=[]
    for i in eval(movies["crew"].iloc[j]):
        if i["job"] == "Director":
            l1.append(i["name"])
    l.append(l1)
len(l)
# Out:
# 4809

# %%
movies["crew"] = l

# %%
dumping_into_sql=movies.copy()

# %%
dumping_into_sql
# Out:
#           id                            original_title  \
# 0      19995                                    Avatar
# 1        285  Pirates of the Caribbean: At World's End
# 2     206647                                   Spectre
# 3      49026                     The Dark Knight Rises
# 4      49529                               John Carter
# ...      ...                                       ...
# 4804    9367                               El Mariachi
# 4805   72766                                 Newlyweds
# 4806  231617                 Signed, Sealed, Delivered
# 4807  126186                          Shanghai Calling
# 4808   25975                         My Date with Drew
#
#                                              genres  \
# 0     [Action, Adventure, Fantasy, Science Fiction]
# 1                      [Adventure, Fantasy, Action]
# 2                        [Action, Adventure, Crime]
# 3                  [Action, Crime, Drama, Thriller]
# ...

# %%
movies
# Out:
#           id                            original_title  \
# 0      19995                                    Avatar
# 1        285  Pirates of the Caribbean: At World's End
# 2     206647                                   Spectre
# 3      49026                     The Dark Knight Rises
# 4      49529                               John Carter
# ...      ...                                       ...
# 4804    9367                               El Mariachi
# 4805   72766                                 Newlyweds
# 4806  231617                 Signed, Sealed, Delivered
# 4807  126186                          Shanghai Calling
# 4808   25975                         My Date with Drew
#
#                                              genres  \
# 0     [Action, Adventure, Fantasy, Science Fiction]
# 1                      [Adventure, Fantasy, Action]
# 2                        [Action, Adventure, Crime]
# 3                  [Action, Crime, Drama, Thriller]
# ...

# %% [markdown]
# # Removing spaces

# %%
# from geners
def space_remover(x):
    l =[]
    for i in movies[x]:
        l1 = []
        for j in i:
            l1.append(j.replace(" ",""))
        l.append(l1)
    return l

# %%
space_remover("keywords")
# Out:
# [['cultureclash',
#   'future',
#   'spacewar',
#   'spacecolony',
#   'society',
#   'spacetravel',
#   'futuristic',
#   'romance',
#   'space',
#   'alien',
#   'tribe',
#   'alienplanet',
#   'cgi',
#   'marine',
#   'soldier',
#   'battle',
#   'loveaffair',
#   'antiwar',
#   'powerrelations',
#   'mindandsoul',
#   '3d'],
#  ['ocean',
#   'drugabuse',
#   'exoticisland',
#   'eastindiatradingcompany',
#   "loveofone'slife",
#   'traitor',
#   'shipwreck',
#   'strongwoman',
#   'ship',
#   'alliance',
#   'calypso',
#   'afterlife',
#   'fighter',
#   'pirate',
#   'swashbuckler',
#   'aftercreditsstinger'],
#  ['spy',
#   'basedonnovel',
#   'secretagent',
#   'sequel',
#   'mi6',
#   'britishsecretservice',
#   'unitedkingdom'],
#  ['dccomics',
#   'crimefighter',
#   'terrorist',
#   'secretidentity',
#   'burglar',
#   'hostagedrama',
#   'timebomb',
#   'gothamcity',
#   'vigilante',
#   'cover-up',
#   'superhero',
#   'villainess',
#   'tragichero',
#   'terrorism',
# ...

# %%
movies["keywords"]=space_remover("keywords")

# %%
movies["cast"]=space_remover("cast")

# %%
movies["crew"]=space_remover("crew")

# %%
movies["genres"]=space_remover("genres")

# %%
movies
# Out:
#           id                            original_title  \
# 0      19995                                    Avatar
# 1        285  Pirates of the Caribbean: At World's End
# 2     206647                                   Spectre
# 3      49026                     The Dark Knight Rises
# 4      49529                               John Carter
# ...      ...                                       ...
# 4804    9367                               El Mariachi
# 4805   72766                                 Newlyweds
# 4806  231617                 Signed, Sealed, Delivered
# 4807  126186                          Shanghai Calling
# 4808   25975                         My Date with Drew
#
#                                             genres  \
# 0     [Action, Adventure, Fantasy, ScienceFiction]
# 1                     [Adventure, Fantasy, Action]
# 2                       [Action, Adventure, Crime]
# 3                 [Action, Crime, Drama, Thriller]
# ...

# %% [markdown]
# # Converting into string

# %%
def into_string(x):
    l = []
    for i in movies[x]:
        l.append(" ".join(i))
    movies[x] = l

# %%
into_string("genres")
into_string("crew")
into_string("cast")
into_string("keywords")

# %%
movies
# Out:
#           id                            original_title  \
# 0      19995                                    Avatar
# 1        285  Pirates of the Caribbean: At World's End
# 2     206647                                   Spectre
# 3      49026                     The Dark Knight Rises
# 4      49529                               John Carter
# ...      ...                                       ...
# 4804    9367                               El Mariachi
# 4805   72766                                 Newlyweds
# 4806  231617                 Signed, Sealed, Delivered
# 4807  126186                          Shanghai Calling
# 4808   25975                         My Date with Drew
#
#                                        genres  \
# 0     Action Adventure Fantasy ScienceFiction
# 1                    Adventure Fantasy Action
# 2                      Action Adventure Crime
# 3                 Action Crime Drama Thriller
# 4             Action Adventure ScienceFiction
# ...

# %%
movies["tags"] = movies["overview"] + " " +movies["genres"] + " " + movies["keywords"] + " " + movies["cast"] + " " + movies["crew"]

# %%
movies["tags"].iloc[0]
# Out:
# 'In the 22nd century, a paraplegic Marine is dispatched to the moon Pandora on a unique mission, but becomes torn between following orders and protecting an alien civilization. Action Adventure Fantasy ScienceFiction cultureclash future spacewar spacecolony society spacetravel futuristic romance space alien tribe alienplanet cgi marine soldier battle loveaffair antiwar powerrelations mindandsoul 3d SamWorthington ZoeSaldana SigourneyWeaver StephenLang MichelleRodriguez JamesCameron'

# %%
movies
# Out:
#           id                            original_title  \
# 0      19995                                    Avatar
# 1        285  Pirates of the Caribbean: At World's End
# 2     206647                                   Spectre
# 3      49026                     The Dark Knight Rises
# 4      49529                               John Carter
# ...      ...                                       ...
# 4804    9367                               El Mariachi
# 4805   72766                                 Newlyweds
# 4806  231617                 Signed, Sealed, Delivered
# 4807  126186                          Shanghai Calling
# 4808   25975                         My Date with Drew
#
#                                        genres  \
# 0     Action Adventure Fantasy ScienceFiction
# 1                    Adventure Fantasy Action
# 2                      Action Adventure Crime
# 3                 Action Crime Drama Thriller
# 4             Action Adventure ScienceFiction
# ...

# %% [markdown]
# # removing NAN values

# %%
movies.isnull().sum()
# Out:
# id                0
# original_title    0
# genres            0
# keywords          0
# overview          3
# cast              0
# crew              0
# tags              3
# dtype: int64

# %%
movies.dropna(inplace = True)

# %%
movies.isnull().sum()
# Out:
# id                0
# original_title    0
# genres            0
# keywords          0
# overview          0
# cast              0
# crew              0
# tags              0
# dtype: int64

# %% [markdown]
# # creating new dataset

# %%
movies_tag_set = movies[["id","original_title","tags"]]

# %%
movies_tag_set
# Out:
#           id                            original_title  \
# 0      19995                                    Avatar
# 1        285  Pirates of the Caribbean: At World's End
# 2     206647                                   Spectre
# 3      49026                     The Dark Knight Rises
# 4      49529                               John Carter
# ...      ...                                       ...
# 4804    9367                               El Mariachi
# 4805   72766                                 Newlyweds
# 4806  231617                 Signed, Sealed, Delivered
# 4807  126186                          Shanghai Calling
# 4808   25975                         My Date with Drew
#
#                                                    tags
# 0     In the 22nd century, a paraplegic Marine is di...
# 1     Captain Barbossa, long believed to be dead, ha...
# 2     A cryptic message from Bond’s past sends him o...
# 3     Following the death of District Attorney Harve...
# ...

# %% [markdown]
# # installing nltk to remove stop words

# %%
#!pip install nltk

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
#only one time execution : nltk.download('stopwords')

# %%
stopword_list = stopwords.words("english")

# %%
for i in range(len(stopword_list)):
    stopword_list.append( stopword_list[i][0].upper() + stopword_list[i][1:len(stopword_list[i])])

# %%
len(stopword_list)
# Out:
# 358

# %%
movies_tag_set["tags"].iloc[0].split()
# Out:
# ['In',
#  'the',
#  '22nd',
#  'century,',
#  'a',
#  'paraplegic',
#  'Marine',
#  'is',
#  'dispatched',
#  'to',
#  'the',
#  'moon',
#  'Pandora',
#  'on',
#  'a',
#  'unique',
#  'mission,',
#  'but',
#  'becomes',
#  'torn',
#  'between',
#  'following',
#  'orders',
#  'and',
#  'protecting',
#  'an',
#  'alien',
#  'civilization.',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'ScienceFiction',
#  'cultureclash',
#  'future',
#  'spacewar',
#  'spacecolony',
#  'society',
#  'spacetravel',
#  'futuristic',
#  'romance',
#  'space',
#  'alien',
#  'tribe',
#  'alienplanet',
#  'cgi',
#  'marine',
#  'soldier',
#  'battle',
#  'loveaffair',
#  'antiwar',
#  'powerrelations',
#  'mindandsoul',
#  '3d',
#  'SamWorthington',
#  'ZoeSaldana',
#  'SigourneyWeaver',
#  'StephenLang',
#  'MichelleRodriguez',
#  'JamesCameron']

# %%
l = []
for j in range(4806):
    
    temp = movies_tag_set["tags"].iloc[j].split()
    i = 0
    while i < len(temp):
        if temp[i] in stopword_list:
            temp.pop(i)
        else:
            i+=1

    l.append(" ".join(temp))

# %%
movies_tag_set.shape
# Out:
# (4806, 3)

# %%
movies_tag_set.head()
# Out:
#        id                            original_title  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
# 3   49026                     The Dark Knight Rises
# 4   49529                               John Carter
#
#                                                 tags
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...

# %%
movies_tag_set["tags"] = l
# Out:
# C:\Users\ishan\AppData\Local\Temp\ipykernel_8568\24361062.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies_tag_set["tags"] = l

# %%
movies_tag_set["tags"]
# Out:
# 0       22nd century, paraplegic Marine dispatched moo...
# 1       Captain Barbossa, long believed dead, come bac...
# 2       cryptic message Bond’s past sends trail uncove...
# 3       Following death District Attorney Harvey Dent,...
# 4       John Carter war-weary, former military captain...
#                               ...
# 4804    El Mariachi wants play guitar carry family tra...
# 4805    newlywed couple's honeymoon upended arrivals r...
# 4806    "Signed, Sealed, Delivered" introduces dedicat...
# 4807    ambitious New York attorney Sam sent Shanghai ...
# 4808    Ever since second grade first saw E.T. Extrate...
# Name: tags, Length: 4806, dtype: object

# %%
l = []
for i in movies_tag_set["tags"]:
    l.append(i.replace(".","").replace(",","").replace("’","").replace("-","").replace("–",""))
movies_tag_set["tags"]=l
# Out:
# C:\Users\ishan\AppData\Local\Temp\ipykernel_8568\2348505802.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies_tag_set["tags"]=l

# %% [markdown]
# # using WordNet to to make similar words a single word

# %%
from nltk.stem import WordNetLemmatizer

# %%
"""
#need to download all this packages
nltk.download("punkt")
nltk.download("wordnet")
nltk.download("omw-1.4")
nltk.download('punkt_tab')
"""
# Out:
# '\n#need to download all this packages\nnltk.download("punkt")\nnltk.download("wordnet")\nnltk.download("omw-1.4")\nnltk.download(\'punkt_tab\')\n'

# %%
lemmatizer = WordNetLemmatizer()

# %%
movies_tag_set["tags"].iloc[0].split()
# Out:
# ['22nd',
#  'century',
#  'paraplegic',
#  'Marine',
#  'dispatched',
#  'moon',
#  'Pandora',
#  'unique',
#  'mission',
#  'becomes',
#  'torn',
#  'following',
#  'orders',
#  'protecting',
#  'alien',
#  'civilization',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'ScienceFiction',
#  'cultureclash',
#  'future',
#  'spacewar',
#  'spacecolony',
#  'society',
#  'spacetravel',
#  'futuristic',
#  'romance',
#  'space',
#  'alien',
#  'tribe',
#  'alienplanet',
#  'cgi',
#  'marine',
#  'soldier',
#  'battle',
#  'loveaffair',
#  'antiwar',
#  'powerrelations',
#  'mindandsoul',
#  '3d',
#  'SamWorthington',
#  'ZoeSaldana',
#  'SigourneyWeaver',
#  'StephenLang',
#  'MichelleRodriguez',
#  'JamesCameron']

# %%
l = []
for i in movies_tag_set["tags"]:
    words = word_tokenize(i)
    lemmatized_words =" ".join([lemmatizer.lemmatize(word) for word in words])
    l.append(lemmatized_words)
len(l)
# Out:
# 4806

# %%
movies_tag_set["tags"] = l
# Out:
# C:\Users\ishan\AppData\Local\Temp\ipykernel_8568\24361062.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies_tag_set["tags"] = l

# %%
movies_tag_set.head()
# Out:
#        id                            original_title  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
# 3   49026                     The Dark Knight Rises
# 4   49529                               John Carter
#
#                                                 tags
# 0  22nd century paraplegic Marine dispatched moon...
# 1  Captain Barbossa long believed dead come back ...
# 2  cryptic message Bonds past sends trail uncover...
# 3  Following death District Attorney Harvey Dent ...
# 4  John Carter warweary former military captain w...

# %% [markdown]
# # vectorizing tags

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
cv = CountVectorizer(max_features = 5000,stop_words = "english")

# %%
vectorized_tags = cv.fit_transform(movies_tag_set["tags"]).toarray()

# %% [markdown]
# # getting similarity between each and every tags

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity = cosine_similarity(vectorized_tags)

# %%
similarity.shape
# Out:
# (4806, 4806)

# %% [markdown]
# # exectuion of main function

# %%
def top_five(movie):
    idx=movies_tag_set[movies_tag_set["original_title"]==movie].index[0]
    listidx=list(enumerate(similarity[idx]))
    similar = sorted(listidx, key = lambda x:x[1], reverse = True)
    
    temp = []
    for i in similar[0:6]:
        MT=movies_tag_set.iloc[i[0]]["original_title"]
        MID=movies_tag_set.iloc[i[0]]["id"]
        temp.append((MID,MT))
    return temp

# %%
def recommendations(movie):
    try:
        return top_five(movie)
    except IndexError :
        return "No such Movie Exist...!!"

# %%
recommendations("Avatar")
# Out:
# [(np.int64(19995), 'Avatar'),
#  (np.int64(679), 'Aliens'),
#  (np.int64(602), 'Independence Day'),
#  (np.int64(7450), 'Titan A.E.'),
#  (np.int64(440), 'Aliens vs Predator: Requiem'),
#  (np.int64(80274), "Ender's Game")]

# %% [markdown]
# # Moving data into python script (VS code)

# %%
import pickle

# %% [markdown]
# ### creating pickle file for similarity matrix

# %%
np.save("similarity.npy",similarity)

# %%
movies_tag_set.to_csv("movies_tag_set.csv",index=False)

# %%
pickle.dump(movies_tag_set.to_dict(),open("movies_tag_Set.pkl","wb"))

# %% [markdown]
# # For Sentiment analysis data preperation

# %% [markdown]
# ### creating review's dataframe

# %%
imdb= pd.read_csv(r"C:\Users\ishan\Desktop\machine learning\movie Recomandation system\dataset\movie reviews\IMDB Dataset.csv")

# %%
imdb["review"].iloc[1].replace("<br />","").replace("\'","").replace("-","").replace(",","").replace(":","")
# Out:
# 'A wonderful little production. The filming technique is very unassuming very oldtimeBBC fashion and gives a comforting and sometimes discomforting sense of realism to the entire piece. The actors are extremely well chosen Michael Sheen not only "has got all the polari" but he has all the voices down pat too! You can truly see the seamless editing guided by the references to Williams diary entries not only is it well worth the watching but it is a terrificly written and performed piece. A masterful production about one of the great masters of comedy and his life. The realism really comes home with the little things the fantasy of the guard which rather than use the traditional dream techniques remains solid then disappears. It plays on our knowledge and our senses particularly with the scenes concerning Orton and Halliwell and the sets (particularly of their flat with Halliwells murals decorating every surface) are terribly well done.'

# %%
imdb.iloc[49999]
# Out:
# review       No one expects the Star Trek movies to be high...
# sentiment                                             negative
# Name: 49999, dtype: object

# %%
imdb["sentiment"].value_counts()
# Out:
# sentiment
# positive    25000
# negative    25000
# Name: count, dtype: int64

# %%
reviews=[]
for review in range(50000):
    reviews.append(imdb["review"].iloc[review].replace("<br />","").replace("\'","").replace("-","").replace(",","").replace(":",""))

# %%
imdb["review"]=reviews

# %%
positive_templates=np.array(imdb[imdb["sentiment"]=="positive"]["review"])

# %%
negative_templates=np.array(imdb[imdb["sentiment"]=="negative"]["review"])

# %%
import random

# Function to generate random reviews
def generate_reviews(num_reviews=100):
    movie_reviews = dict()
    movie_id = []
    reviews = []
    for id in movies["id"]:
        
        for _ in range(num_reviews):
            sentiment = random.choice(['positive', 'negative'])
        
            if sentiment == 'positive':
                review = random.choice(positive_templates)
            else:
                review = random.choice(negative_templates)
        
            reviews.append(review)
            movie_id.append(id)
        
    movie_reviews = {"movie_id":movie_id,
                     "reviews":reviews}
    return movie_reviews

# Generate 50,000 reviews
reviews = generate_reviews()

# Create DataFrame
import pandas as pd
df = pd.DataFrame(reviews)

# Display the first few reviews

# %%
df
# Out:
#         movie_id                                            reviews
# 0          19995  Recently released on British DVD this is a goo...
# 1          19995  I first encountered this show when I was stayi...
# 2          19995  Do you guys wanna know a secret?. This movie s...
# 3          19995  This film is outstanding! On this date of APR ...
# 4          19995  This film is underrated. I loved it. It was tr...
# ...          ...                                                ...
# 480595     25975  Hello peopleI cannot believe that "Shades" fro...
# 480596     25975  I rented "The China Syndrome" recently mainly ...
# 480597     25975  The DVD version consists of 2 episodes the par...
# 480598     25975  Having read the unemployed critics review I we...
# 480599     25975  I watch a lot of movies. A LOT of movies. Gett...
#
# [480600 rows x 2 columns]

# %%
movies
# Out:
#           id                            original_title  \
# 0      19995                                    Avatar
# 1        285  Pirates of the Caribbean: At World's End
# 2     206647                                   Spectre
# 3      49026                     The Dark Knight Rises
# 4      49529                               John Carter
# ...      ...                                       ...
# 4804    9367                               El Mariachi
# 4805   72766                                 Newlyweds
# 4806  231617                 Signed, Sealed, Delivered
# 4807  126186                          Shanghai Calling
# 4808   25975                         My Date with Drew
#
#                                        genres  \
# 0     Action Adventure Fantasy ScienceFiction
# 1                    Adventure Fantasy Action
# 2                      Action Adventure Crime
# 3                 Action Crime Drama Thriller
# 4             Action Adventure ScienceFiction
# ...

# %% [markdown]
# # manipulating dumping_into_sql

# %%
#execute each line in different cell only for one time
"""
dumping_into_sql
dumping_into_sql.nunique()
dumping_into_sql=dumping_into_sql.drop(index=1365)
dumping_into_sql=dumping_into_sql.drop(index=3655)
dumping_into_sql=dumping_into_sql.drop(index=972)
dumping_into_sql=dumping_into_sql.drop(index=974)
dumping_into_sql=dumping_into_sql.drop(index=1362)
dumping_into_sql=dumping_into_sql.drop(index=3653)
dumping_into_sql.shape
for col in ['genres', 'keywords', 'cast', 'crew']:
    dumping_into_sql[col] = dumping_into_sql[col].apply(lambda x: ','.join(x)) 
"""
# Out:
# "\ndumping_into_sql\ndumping_into_sql.nunique()\ndumping_into_sql=dumping_into_sql.drop(index=1365)\ndumping_into_sql=dumping_into_sql.drop(index=3655)\ndumping_into_sql=dumping_into_sql.drop(index=972)\ndumping_into_sql=dumping_into_sql.drop(index=974)\ndumping_into_sql=dumping_into_sql.drop(index=1362)\ndumping_into_sql=dumping_into_sql.drop(index=3653)\ndumping_into_sql.shape\nfor col in ['genres', 'keywords', 'cast', 'crew']:\n    dumping_into_sql[col] = dumping_into_sql[col].apply(lambda x: ','.join(x)) \n"

# %% [markdown]
# # Database Designing

# %% [markdown]
# ### for movies information

# %%
#run it only for one time 
"""
# Already created a database "movies_info" in sql workbench
user = "root"
host="localhost"
password="Cybrom#1123"
database="movies_info"

engine = create_engine(f"mysql+pymysql://{user}:{password}@{host}/{database}")"""
# Out:
# '\n# Already created a database "movies_info" in sql workbench\nuser = "root"\nhost="localhost"\npassword="Cybrom#1123"\ndatabase="movies_info"\n\nengine = create_engine(f"mysql+pymysql://{user}:{password}@{host}/{database}")'

# %%
#pd.read_sql("show databases", con=engine)

# %%
#pd.read_sql("show tables",con=engine)

# %%
#dumping_into_sql.to_sql('movies', con=engine, if_exists='replace', index=False)

# %% [markdown]
# ### for movies reviews

# %%
#df

# %%
#df.to_sql("reviews",con=engine,index=False)
